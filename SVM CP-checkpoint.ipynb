# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("C:/Users/karim/Downloads/Electric_cars_dataset.csv")
df
# Out:
#             ID  VIN (1-10)     County        City State  ZIP Code  Model Year  \
# 0      EV33174  5YJ3E1EC6L  Snohomish    LYNNWOOD    WA   98037.0      2020.0
# 1      EV40247  JN1AZ0CP8B     Skagit  BELLINGHAM    WA   98229.0      2011.0
# 2      EV12248  WBY1Z2C56F     Pierce      TACOMA    WA   98422.0      2015.0
# 3      EV55713  1G1RD6E44D       King     REDMOND    WA   98053.0      2013.0
# 4      EV28799  1G1FY6S05K     Pierce    PUYALLUP    WA   98375.0      2019.0
# ...        ...         ...        ...         ...   ...       ...         ...
# 64348   EV6357  KNDCE3LG7L       King     SEATTLE    WA   98144.0      2020.0
# 64349    EV423  JTDKN3DP2D     Pierce      TACOMA    WA   98402.0      2013.0
# 64350  EV27852  1G1FX6S05J       King     SEATTLE    WA   98119.0      2018.0
# 64351    EV830  WP1AE2A24H       King     SEATTLE    WA   98115.0      2017.0
# 64352  EV11120  1N4BZ1CP8K      Lewis      TOLEDO    WA   98591.0      2019.0
#
# ...

# %%
df.columns
# Out:
# Index(['ID', 'VIN (1-10)', 'County', 'City', 'State', 'ZIP Code', 'Model Year',
#        'Make', 'Model', 'Electric Vehicle Type',
#        'Clean Alternative Fuel Vehicle (CAFV) Eligibility', 'Electric Range',
#        'Base MSRP', 'Legislative District', 'DOL Vehicle ID',
#        'Vehicle Location', 'Electric Utility', 'Expected Price ($1k)'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64353 entries, 0 to 64352
# Data columns (total 18 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   ID                                                 64353 non-null  object
#  1   VIN (1-10)                                         64353 non-null  object
#  2   County                                             64349 non-null  object
#  3   City                                               64344 non-null  object
#  4   State                                              64342 non-null  object
#  5   ZIP Code                                           64347 non-null  float64
#  6   Model Year                                         64346 non-null  float64
#  7   Make                                               64349 non-null  object
# ...

# %%
df.describe()
# Out:
#            ZIP Code    Model Year  Electric Range      Base MSRP  \
# count  64347.000000  64346.000000    64353.000000   64353.000000
# mean   98143.452888   2018.186212      106.948985    2524.990754
# std     2856.064329      2.726742      104.093919   12402.895104
# min      745.000000   1993.000000        0.000000       0.000000
# 25%    98052.000000   2017.000000       14.000000       0.000000
# 50%    98121.000000   2018.000000       73.000000       0.000000
# 75%    98370.000000   2021.000000      215.000000       0.000000
# max    99701.000000   2022.000000      337.000000  845000.000000
#
#        Legislative District  DOL Vehicle ID
# count          64184.000000    6.435300e+04
# mean              29.951904    1.972905e+08
# std               14.661124    1.069466e+08
# min                0.000000    4.385000e+03
# 25%               19.000000    1.372865e+08
# 50%               34.000000    1.753776e+08
# 75%               43.000000    2.299039e+08
# ...

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
df.isnull().sum() * 100 / len(df)
# Out:
# ID                                                   0.000000
# VIN (1-10)                                           0.000000
# County                                               0.006216
# City                                                 0.013985
# State                                                0.017093
# ZIP Code                                             0.009324
# Model Year                                           0.010878
# Make                                                 0.006216
# Model                                                0.020201
# Electric Vehicle Type                                0.000000
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    0.000000
# Electric Range                                       0.000000
# Base MSRP                                            0.000000
# Legislative District                                 0.262614
# DOL Vehicle ID                                       0.000000
# ...

# %%
for col in df.select_dtypes(include=['float64', 'int64']).columns:
    df[col].fillna(df[col].mean(), inplace=True)
for col in df.select_dtypes(include=['object']).columns:
    df[col].fillna(df[col].mode()[0], inplace=True)

print(df.isna().sum())
# Out:
# ID                                                   0
# VIN (1-10)                                           0
# County                                               0
# City                                                 0
# State                                                0
# ZIP Code                                             0
# Model Year                                           0
# Make                                                 0
# Model                                                0
# Electric Vehicle Type                                0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    0
# Electric Range                                       0
# Base MSRP                                            0
# Legislative District                                 0
# DOL Vehicle ID                                       0
# Vehicle Location                                     0
# Electric Utility                                     0
# ...

# %%
from sklearn.preprocessing import LabelEncoder
df["Expected Price ($1k)"] = pd.to_numeric(df["Expected Price ($1k)"], errors='coerce')



encode_cols = ['County', 'City', 'State', 'Make', 'Model', 
               'Electric Vehicle Type', 'Clean Alternative Fuel Vehicle (CAFV) Eligibility', 
               'Vehicle Location', 'Electric Utility']

le = LabelEncoder()
for col in encode_cols:
    df[col] = le.fit_transform(df[col])


print(df.head())
# Out:
#         ID  VIN (1-10)  County  City  State  ZIP Code  Model Year  Make  \
# 0  EV33174  5YJ3E1EC6L     120   271     35   98037.0      2020.0    28
# 1  EV40247  JN1AZ0CP8B     118    38     35   98229.0      2011.0    22
# 2  EV12248  WBY1Z2C56F      95   473     35   98422.0      2015.0     3
# 3  EV55713  1G1RD6E44D      60   391     35   98053.0      2013.0     5
# 4  EV28799  1G1FY6S05K      95   380     35   98375.0      2019.0     5
#
#    Model  Electric Vehicle Type  \
# 0     57                      0
# 1     53                      0
# 2     45                      0
# 3     96                      1
# 4     15                      0
#
#    Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0                                                  0             308
# 1                                                  0              73
# 2                                                  0              81
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# All numeric columns after encoding
all_numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns

plt.figure(figsize=(20,16))

for i, col in enumerate(all_numeric_cols, 1):
    plt.subplot(4, 5, i)  # adjust grid size depending on number of columns
    sns.boxplot(x=col, data=df, color='lightgreen', fliersize=5)
    plt.title(col)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


df["Expected Price ($1k)"] = pd.to_numeric(df["Expected Price ($1k)"], errors='coerce')
df.fillna(df.mean(numeric_only=True), inplace=True)

# Correlation heatmap
plt.figure(figsize=(14,10))
sns.heatmap(df.select_dtypes(include=['int64', 'float64']).corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.show()

# %%
from sklearn.model_selection import train_test_split

X = df[['Make', 'Model Year', 'Electric Vehicle Type', 
        'Clean Alternative Fuel Vehicle (CAFV) Eligibility', 'Electric Range']]

# One-hot encode categorical features
X = pd.get_dummies(X, drop_first=True)

Y = pd.to_numeric(df['Expected Price ($1k)'], errors='coerce')


#split data
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,random_state = 0, test_size = 0.2)

print("X_train shape:",X_train.shape)
print("X_test shape:",X_test.shape)
print("Y_train shape:",Y_train.shape)
print("Y_test shape:",Y_test.shape)
# Out:
# X_train shape: (51482, 5)
# X_test shape: (12871, 5)
# Y_train shape: (51482,)
# Y_test shape: (12871,)

# %%
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)


# Scale features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Train SVR with RBF kernel
svr_rbf = SVR(kernel='rbf', C=100, epsilon=0.1, gamma='scale')
svr_rbf.fit(X_train_scaled, Y_train)

# Predict and evaluate
Y_train_pred = svr_rbf.predict(X_train_scaled)
Y_test_pred = svr_rbf.predict(X_test_scaled)

print("Train R^2:", r2_score(Y_train, Y_train_pred))
print("Test R^2:", r2_score(Y_test, Y_test_pred))
# Out:
# Train R^2: 0.7653187433713382
# Test R^2: 0.7150238340041606

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR

# Hyperparameter grid
param_grid = {
    'C': [1, 10, 100, 500],
    'epsilon': [0.01, 0.1, 0.5, 1],
    'gamma': ['scale', 'auto']
}

# Grid search with 5-fold CV
grid_search = GridSearchCV(SVR(kernel='rbf'), param_grid, cv=5, scoring='r2', n_jobs=-1)
grid_search.fit(X_train_scaled, Y_train)

# Best SVR model
best_svr = grid_search.best_estimator_

# Predict and evaluate
Y_train_pred = best_svr.predict(X_train_scaled)
Y_test_pred = best_svr.predict(X_test_scaled)

print("Best parameters:", grid_search.best_params_)
print("Train R^2:", r2_score(Y_train, Y_train_pred))
print("Test R^2:", r2_score(Y_test, Y_test_pred))
